# %% [markdown]
# ## Make a list of all of the filenames you want to open
#
# You _could_ do this manually, but I suggest using my favorite-named tool: **glob**! It works like this:
#
# ```python
# # Get a list of all CSV files in the current directory
# # that start with "sales," e.g. sales-2020.csv, sales-2015.csv, etc
# import glob
# filenames = glob.glob("sales-*.csv")
# ```
#
# * _**Tip:** `*` means "match anything." _It's different than the `.*` we used in class, but it's the same idea._
# * _**Tip:** Make sure your list includes both 2015 *and* 2019. Remember, some are `xls` and some are `xlsx`!

# %%
# Should maybe not have downloaded those sheets! lol

# !ls
# Out:
# 6449.40s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 01 - Data Acquisition.ipynb 2016_brooklyn.xls
# 02 - Data Compilation.ipynb 2016_brooklyn.xls.1
# 03 - Data Analysis.ipynb    2017_brooklyn.xls
# 04 - Data Exploration.ipynb 2017_brooklyn.xls.1
# 2009_brooklyn.xls           2018_brooklyn.xlsx
# 2009_brooklyn.xls.1         2018_brooklyn.xlsx.1
# 2010_brooklyn.xls           2019_brooklyn.xlsx
# 2010_brooklyn.xls.1         2019_brooklyn.xlsx.1
# 2011_brooklyn.xls           2020_brooklyn.xlsx
# 2011_brooklyn.xls.1         2020_brooklyn.xlsx.1
# 2012_brooklyn.xls           2021_brooklyn.xlsx
# 2012_brooklyn.xls.1         2021_brooklyn.xlsx.1
# 2013_brooklyn.xls           cleaned.csv
# 2013_brooklyn.xls.1         merged.csv
# 2014_brooklyn.xls           sales_2007_brooklyn.xls
# 2014_brooklyn.xls.1         sales_2008_brooklyn.xls
# 2015_brooklyn.xls           urls.txt
# 2015_brooklyn.xls.1

# %%
# I take it back, the extension was different so it's fine

import glob
files = glob.glob("20*.xls")
files2 = glob.glob("20*.xlsx")
files3 = glob.glob("sales*.xls")

for file in files2:
    files.append(file)

for file in files3:
    files.append(file)

files
# Out:
# ['2014_brooklyn.xls',
#  '2013_brooklyn.xls',
#  '2012_brooklyn.xls',
#  '2015_brooklyn.xls',
#  '2009_brooklyn.xls',
#  '2017_brooklyn.xls',
#  '2010_brooklyn.xls',
#  '2011_brooklyn.xls',
#  '2016_brooklyn.xls',
#  '2018_brooklyn.xlsx',
#  '2021_brooklyn.xlsx',
#  '2020_brooklyn.xlsx',
#  '2019_brooklyn.xlsx',
#  'sales_2007_brooklyn.xls',
#  'sales_2008_brooklyn.xls']

# %% [markdown]
# ## Open one of them with pandas just to test it out. Any of them!
#
# You'll need to use `skiprows=` to skip the first few rows, as they're informational and not actual data.
#
# * _**Tip:** Yes, the column names are awful right now, but you'll fix them later_

# %%
import pandas as pd

df = pd.read_excel('2019_brooklyn.xlsx', skiprows=4)

df.head(5)
# Out:
#    BOROUGH\n NEIGHBORHOOD\n BUILDING CLASS CATEGORY\n  \
# 0          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 1          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 2          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 3          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 4          3     BATH BEACH   01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n  EASE-MENT\n  \
# 0                                1     6363     22          NaN
# 1                                1     6363     48          NaN
# 2                                1     6363     48          NaN
# 3                                1     6364     74          NaN
# 4                                1     6367     42          NaN
#
#   BUILDING CLASS AS OF FINAL ROLL 18/19           ADDRESS\n  \
# 0                                    A9    8645 16TH AVENUE
# 1                                    A9  12 BAY 13TH STREET
# 2                                    A9  12 BAY 13TH STREET
# 3                                    A5  72 BAY 14TH STREET
# 4                                    S1    1730 86TH STREET
#
#   APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  \
# 0                NaN  ...                  1.0                 0.0
# 1                NaN  ...                  1.0                 0.0
# 2                NaN  ...                  1.0                 0.0
# 3                NaN  ...                  1.0                 0.0
# 4                NaN  ...                  1.0                 1.0
#
#    TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n  \
# 0            1.0              2058.0               1492.0        1930.0
# 1            1.0              3142.0               3200.0        1999.0
# 2            1.0              3142.0               3200.0        1999.0
# 3            1.0              2492.0                972.0        1950.0
# 4            2.0              1342.0               1920.0        1926.0
#
#    TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  \
# 0                            1                                A9            0
# 1                            1                                A9            0
# 2                            1                                A9            0
# 3                            1                                A5            0
# 4                            1                                S1      1630000
#
#    SALE DATE\n
# 0   2019-04-23
# 1   2019-02-27
# 2   2019-02-11
# 3   2019-08-15
# 4   2019-02-08
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Now open another one.
#
# Keep opening them with the same `.read_excel` options until you find one with bad headers. **UGH!!!** They all have different `skiprows=` values!

# %%
df = pd.read_excel('2018_brooklyn.xlsx', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n NEIGHBORHOOD\n BUILDING CLASS CATEGORY\n  \
# 0          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 1          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 2          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 3          3     BATH BEACH   01 ONE FAMILY DWELLINGS
# 4          3     BATH BEACH   01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n  EASE-MENT\n  \
# 0                                1     6360     23          NaN
# 1                                1     6366     69          NaN
# 2                                1     6366     72          NaN
# 3                                1     6367     41          NaN
# 4                                1     6371     20          NaN
#
#   BUILDING CLASS AS OF FINAL ROLL 18/19             ADDRESS\n  \
# 0                                    A5      8645 15TH AVENUE
# 1                                    A1  8658 BAY 16TH STREET
# 2                                    A1  8664 BAY 16TH STREET
# 3                                    S1      1728 86TH STREET
# 4                                    A9  75 BAY 20TH   STREET
#
#   APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  \
# 0                NaN  ...                  1.0                 0.0
# 1                NaN  ...                  1.0                 0.0
# 2                NaN  ...                  1.0                 0.0
# 3                NaN  ...                  1.0                 1.0
# 4                NaN  ...                  1.0                 0.0
#
#    TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n  \
# 0            1.0              1547.0               1428.0        1930.0
# 1            1.0              4833.0               1724.0        1930.0
# 2            1.0              4833.0               2300.0        1925.0
# 3            2.0              1342.0               1920.0        1931.0
# 4            1.0              2417.0               1742.0        1930.0
#
#    TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  \
# 0                            1                                A5       750000
# 1                            1                                A1            0
# 2                            1                                A1      1720000
# 3                            1                                S1      1380000
# 4                            1                                A9       710000
#
#    SALE DATE\n
# 0   2018-05-18
# 1   2018-10-25
# 2   2018-12-12
# 3   2018-07-26
# 4   2018-02-21
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2020_brooklyn.xlsx', skiprows=6)
df.head(5)
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0      NaN          NaN                      NaN                  NaN     NaN
# 1      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6359.0
# 2      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6360.0
# 3      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6360.0
# 4      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6362.0
#
#     LOT  EASE-MENT BUILDING CLASS AT PRESENT             ADDRESS  \
# 0   NaN        NaN                       NaN                 NaN
# 1  70.0        NaN                        S1    8684 15TH AVENUE
# 2  48.0        NaN                        A5  14 BAY 10TH STREET
# 3  56.0        NaN                        A5  30 BAY 10TH STREET
# 4  23.0        NaN                        A9  43 BAY 11TH STREET
#
#   APARTMENT NUMBER  ...  RESIDENTIAL\nUNITS  COMMERCIAL\nUNITS  TOTAL \nUNITS  \
# 0              NaN  ...                 NaN                NaN            NaN
# 1              NaN  ...                 1.0                1.0            2.0
# 2              NaN  ...                 1.0                0.0            1.0
# 3              NaN  ...                 1.0                0.0            1.0
# 4              NaN  ...                 1.0                0.0            1.0
#
#    LAND \nSQUARE FEET  GROSS \nSQUARE FEET  YEAR BUILT  \
# 0                 NaN                  NaN         NaN
# 1              1933.0               4080.0      1930.0
# 2              2513.0               1428.0      1930.0
# 3              1547.0               1428.0      1930.0
# 4              2280.0               1052.0      1901.0
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS\nAT TIME OF SALE SALE PRICE  \
# 0                        NaN                              NaN        NaN
# 1                        1.0                               S1  1300000.0
# 2                        1.0                               A5   849000.0
# 3                        1.0                               A5    75000.0
# 4                        1.0                               A9        0.0
#
#    SALE DATE
# 0        NaT
# 1 2020-04-28
# 2 2020-03-18
# 3 2020-11-30
# 4 2020-11-04
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2021_brooklyn.xlsx', skiprows=6)
df.head(5)
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0      NaN          NaN                      NaN                  NaN     NaN
# 1      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6364.0
# 2      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6364.0
# 3      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6367.0
# 4      3.0   BATH BEACH  01 ONE FAMILY DWELLINGS                    1  6370.0
#
#     LOT  EASE-MENT BUILDING CLASS AT PRESENT             ADDRESS  \
# 0   NaN        NaN                       NaN                 NaN
# 1  74.0        NaN                        A5     72 BAY 14TH ST.
# 2  74.0        NaN                        A5  72 BAY 14TH STREET
# 3  24.0        NaN                        A9   8645 BAY 16 STREE
# 4  65.0        NaN                        A9  26 BAY 20TH STREET
#
#   APARTMENT NUMBER  ...  RESIDENTIAL\nUNITS  COMMERCIAL\nUNITS  TOTAL \nUNITS  \
# 0              NaN  ...                 NaN                NaN            NaN
# 1              NaN  ...                 1.0                0.0            1.0
# 2              NaN  ...                 1.0                0.0            1.0
# 3              NaN  ...                 1.0                0.0            1.0
# 4              NaN  ...                 1.0                0.0            1.0
#
#    LAND \nSQUARE FEET  GROSS \nSQUARE FEET  YEAR BUILT  \
# 0                 NaN                  NaN         NaN
# 1              2492.0                972.0      1950.0
# 2              2492.0                972.0      1950.0
# 3              1571.0               1456.0      1935.0
# 4              2417.0               1584.0      1930.0
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS\nAT TIME OF SALE SALE PRICE  \
# 0                        NaN                              NaN        NaN
# 1                        1.0                               A5        0.0
# 2                        1.0                               A5   890000.0
# 3                        1.0                               A9   925000.0
# 4                        1.0                               A9        0.0
#
#    SALE DATE
# 0        NaT
# 1 2021-05-21
# 2 2021-10-08
# 3 2021-11-03
# 4 2021-09-04
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2009_brooklyn.xls', skiprows=3)
df.head(5)
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   6360
# 1  01  ONE FAMILY HOMES                                            1   6360
# 2  01  ONE FAMILY HOMES                                            1   6364
# 3  01  ONE FAMILY HOMES                                            1   6364
# 4  01  ONE FAMILY HOMES                                            1   6364
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   75                                  A5
# 1  157                                  A5
# 2    2                                  A5
# 3    8                                  B3
# 4   72                                  A5
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  72 BAY 10TH STREET                                          ...
# 1  36 BAY 10TH STREET                                          ...
# 2  1649 BENSON AVENUE                                          ...
# 3  1631 BENSON AVENUE                                          ...
# 4  68 BAY 14TH   STREET                                        ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              2513
# 1                  1                 0            1              1547
# 2                  1                 0            1              1638
# 3                  2                 0            2              2688
# 4                  1                 0            1              1950
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1428        1930                          1
# 1               1428        1930                          1
# 2                972        1930                          1
# 3               1867        1930                          1
# 4                972        1950                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A5     155356 2009-08-11
# 1                              A5     505000 2009-03-05
# 2                              A5          0 2009-10-23
# 3                              A1     410000 2009-03-11
# 4                              A5     455000 2009-08-21
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2010_brooklyn.xls', skiprows=3)
df.head(5)
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   6365
# 1  01  ONE FAMILY HOMES                                            1   6366
# 2  01  ONE FAMILY HOMES                                            1   6366
# 3  01  ONE FAMILY HOMES                                            1   6370
# 4  01  ONE FAMILY HOMES                                            1   6380
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   44                                  S1
# 1   69                                  A1
# 2   69                                  A1
# 3   66                                  A9
# 4   26                                  A9
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  1690 86TH   STREET                                          ...
# 1  8658 BAY 16TH STREET                                        ...
# 2  8658 BAY 16TH STREET                                        ...
# 3  28 BAY 20TH STREET                                          ...
# 4  33 BAY 29TH   STREET                                        ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 1            2              1473
# 1                  1                 0            1              4833
# 2                  1                 0            1              4833
# 3                  1                 0            1              2417
# 4                  1                 0            1              2465
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1656        1931                          1
# 1               1724        1930                          1
# 2               1724        1930                          1
# 3               1584        1930                          1
# 4               2043        1920                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              S1     680000 2010-06-30
# 1                              A1          0 2010-06-18
# 2                              A1          0 2010-05-26
# 3                              A9          0 2010-01-09
# 4                              A9     618000 2010-11-02
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2011_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   6373
# 1  01  ONE FAMILY HOMES                                            1   6380
# 2  01  ONE FAMILY HOMES                                            1   6399
# 3  01  ONE FAMILY HOMES                                            1   6399
# 4  01  ONE FAMILY HOMES                                            1   6408
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   88                                  A1
# 1   71                                  A5
# 2    4                                  S1
# 3    7                                  S1
# 4   48                                  S1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  92 BAY 23RD STREET                                          ...
# 1  8668 BAY PARKWAY                                            ...
# 2  1665 BATH AVENUE                                            ...
# 3  1657 BATH AVENUE                                            ...
# 4  1967 BATH AVENUE                                            ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              2790
# 1                  1                 0            1              1740
# 2                  1                 1            2              1260
# 3                  1                 1            2              1260
# 4                  1                 1            2              1583
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1376        1940                          1
# 1               1782        1960                          1
# 2               1440        1940                          1
# 3               1440        1930                          1
# 4               2052        1920                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A1          0 2011-02-08
# 1                              A5     610000 2011-10-24
# 2                              S1          0 2011-07-11
# 3                              S1     468000 2011-06-13
# 4                              S1          0 2011-11-11
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2012_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0                                                                    4
# 1                                                                    4
# 2                                                                    4
# 3                                                                    4
# 4                                                                    4
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6370   1308                                      RP
# 1     6370   1310                                      RP
# 2     6370   1312                                      RP
# 3     6370   1313                                      RP
# 4     6370   1321                                      RP
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ...  \
# 0  88 BAY 20TH   STREET                            P7            ...
# 1  88 BAY 20TH   STREET                            P9            ...
# 2  88 BAY 20TH   STREET                            P11           ...
# 3  88 BAY 20TH   STREET                            P12           ...
# 4  98 BAY 20TH   STREET                            P1            ...
#
#    RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  LAND SQUARE FEET\n  \
# 0                    0                   0              1                   0
# 1                    0                   0              1                   0
# 2                    0                   0              1                   0
# 3                    0                   0              1                   0
# 4                    0                   0              1                   0
#
#    GROSS SQUARE FEET\n  YEAR BUILT\n  TAX CLASS AT TIME OF SALE\n  \
# 0                    0          2011                            4
# 1                    0          2011                            4
# 2                    0          2011                            4
# 3                    0          2011                            4
# 4                    0          2011                            4
#
#    BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  SALE DATE\n
# 0                                RP            0   2012-11-19
# 1                                RP            0   2012-11-12
# 2                                RP            0   2012-11-13
# 3                                RP            0   2012-11-13
# 4                                RP            0   2012-12-07
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2013_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     50                                      A5
# 1     6360     67                                      A5
# 2     6361     14                                      A5
# 3     6361     21                                      A5
# 4     6363     23                                      A9
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ...  \
# 0  18 BAY 10TH   STREET                                          ...
# 1  56 BAY 10TH STREET                                            ...
# 2  63 BAY 10TH   STREET                                          ...
# 3  45 BAY 10TH   STREET                                          ...
# 4  8641 16TH AVENUE                                              ...
#
#    RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  LAND SQUARE FEET\n  \
# 0                    1                   0              1                1547
# 1                    1                   0              1                1547
# 2                    1                   0              1                1933
# 3                    1                   0              1                1933
# 4                    1                   0              1                2058
#
#    GROSS SQUARE FEET\n  YEAR BUILT\n  TAX CLASS AT TIME OF SALE\n  \
# 0                 1428          1930                            1
# 1                 1428          1930                            1
# 2                 1660          1930                            1
# 3                 1660          1930                            1
# 4                 1492          1930                            1
#
#    BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  SALE DATE\n
# 0                                A5       505000   2013-09-05
# 1                                A5       690000   2013-11-19
# 2                                A5       638000   2013-10-04
# 3                                A5       729000   2013-09-26
# 4                                A9       560000   2013-06-06
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2014_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     14                                      A5
# 1     6363     22                                      A9
# 2     6363    119                                      A9
# 3     6373     55                                      S1
# 4     6374     67                                      S1
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ...  \
# 0  8663 15TH   AVENUE                                            ...
# 1  8645 16TH   AVENUE                                            ...
# 2  8651 16 AVENUE                                                ...
# 3  1950 86TH STREET                                              ...
# 4  8642 20TH   AVENUE                                            ...
#
#    RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  LAND SQUARE FEET\n  \
# 0                    1                   0              1                1547
# 1                    1                   0              1                2058
# 2                    1                   0              1                2058
# 3                    1                   1              2                1917
# 4                    1                   1              2                1740
#
#    GROSS SQUARE FEET\n  YEAR BUILT\n  TAX CLASS AT TIME OF SALE\n  \
# 0                 2224          1930                            1
# 1                 1492          1930                            1
# 2                 1492          1930                            1
# 3                 2870          1931                            1
# 4                 3240          1925                            1
#
#    BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  SALE DATE\n
# 0                                A5       450000   2014-09-08
# 1                                A9            0   2014-06-23
# 2                                A9       670000   2014-04-16
# 3                                S1            0   2014-07-28
# 4                                S1       828000   2014-03-19
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2015_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     22                                      A5
# 1     6361     17                                      A5
# 2     6371     60                                      A9
# 3     6372     48                                      S1
# 4     6373     73                                      A1
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ...  \
# 0  8647 15TH AVENUE                                              ...
# 1  55 BAY 10TH   STREET                                          ...
# 2  8620 19TH   AVENUE                                            ...
# 3  1906 86TH   STREET                                            ...
# 4  50 BAY 23RD STREET                                            ...
#
#    RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  LAND SQUARE FEET\n  \
# 0                    1                   0              1                1547
# 1                    1                   0              1                1933
# 2                    1                   0              1                2417
# 3                    1                   1              2                1900
# 4                    1                   0              1                2417
#
#    GROSS SQUARE FEET\n  YEAR BUILT\n  TAX CLASS AT TIME OF SALE\n  \
# 0                 1428          1930                            1
# 1                 1660          1930                            1
# 2                 2106          1930                            1
# 3                 2090          1931                            1
# 4                 1672          1930                            1
#
#    BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  SALE DATE\n
# 0                                A5       758000   2015-03-31
# 1                                A5       778000   2015-06-15
# 2                                A9            0   2015-09-16
# 3                                S1      1365000   2015-05-29
# 4                                A1       750000   2015-12-17
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('2016_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     13                                      A5
# 1     6361     11                                      A5
# 2     6364      2                                      A5
# 3     6364     72                                      A5
# 4     6371     79                                      A5
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ...  \
# 0  8665 15TH   AVENUE                                            ...
# 1  71 BAY 10TH   STREET                                          ...
# 2  1649 BENSON AVENUE                                            ...
# 3  68 BAY 14TH STREET                                            ...
# 4  8668 19TH AVENUE                                              ...
#
#    RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  LAND SQUARE FEET\n  \
# 0                    1                   0              1                1547
# 1                    1                   0              1                2900
# 2                    1                   0              1                1638
# 3                    1                   0              1                1950
# 4                    1                   0              1                2223
#
#    GROSS SQUARE FEET\n  YEAR BUILT\n  TAX CLASS AT TIME OF SALE\n  \
# 0                 2224          1930                            1
# 1                 1660          1930                            1
# 2                  972          1930                            1
# 3                  972          1950                            1
# 4                 2520          1930                            1
#
#    BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  SALE DATE\n
# 0                                A5            0   2016-05-25
# 1                                A5       829000   2016-04-05
# 2                                A5            0   2016-10-06
# 3                                A5       790000   2016-06-21
# 4                                A5       788000   2016-03-31
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('sales_2007_brooklyn.xls', skiprows=3)
df.head(5)
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   6361
# 1  01  ONE FAMILY HOMES                                            1   6363
# 2  01  ONE FAMILY HOMES                                            1   6363
# 3  01  ONE FAMILY HOMES                                            1   6364
# 4  01  ONE FAMILY HOMES                                            1   6371
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   19                                  A5
# 1   37                                  A5
# 2   62                                  A9
# 3   47                                  S1
# 4   19                                  A9
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  51 BAY 10TH   STREET                                        ...
# 1  8611 16TH   AVENUE                                          ...
# 2  44 BAY 13TH STREET                                          ...
# 3  1656 86 STREET                                              ...
# 4  79 BAY 20 STREET                                            ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1933
# 1                  1                 0            1              1893
# 2                  1                 0            1              3575
# 3                  1                 1            2              1248
# 4                  1                 0            1              2320
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1660        1930                          1
# 1               1714        1930                          1
# 2               2104        1901                          1
# 3               1620        1901                          1
# 4               1956        1930                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A5     649000 2007-08-31
# 1                              A5     520000 2007-05-22
# 2                              A9          0 2007-11-27
# 3                              S1     645000 2007-04-18
# 4                              A9          0 2007-09-12
#
# [5 rows x 21 columns]

# %%
df = pd.read_excel('sales_2008_brooklyn.xls', skiprows=3)
df.head(5)
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   6360
# 1  01  ONE FAMILY HOMES                                            1   6360
# 2  01  ONE FAMILY HOMES                                            1   6363
# 3  01  ONE FAMILY HOMES                                            1   6372
# 4  01  ONE FAMILY HOMES                                            1   6392
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   49                                  A5
# 1   71                                  A5
# 2   64                                  B2
# 3   34                                  A9
# 4   26                                  A2
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  16 BAY 10TH   STREET                                        ...
# 1  64 BAY 10TH   STREET                                        ...
# 2  48 BAY 13TH STREET                                          ...
# 3  8637 19TH   AVENUE                                          ...
# 4  121 BAY 7TH   STREET                                        ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1547
# 1                  1                 0            1              1547
# 2                  2                 0            2              4008
# 3                  1                 0            1              2417
# 4                  1                 0            1              1933
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1428        1930                          1
# 1               1428        1930                          1
# 2               3898        2009                          1
# 3               2154        1930                          1
# 4               1320        1940                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A5     555000 2008-06-13
# 1                              A5     505000 2008-05-22
# 2                              A9     745000 2008-04-15
# 3                              A9          0 2008-12-05
# 4                              A2     530000 2008-05-07
#
# [5 rows x 21 columns]

# %%
# I opened all of them and am not sure which header I'm supposed to think is uniquely bad. Maybe I opened a bad one first ?

df = pd.read_excel('2017_brooklyn.xls', skiprows=4)
df.head(5)
# Out:
#    BOROUGH\n NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# 0          3     BATH BEACH  01 ONE FAMILY DWELLINGS
# 1          3     BATH BEACH  01 ONE FAMILY DWELLINGS
# 2          3     BATH BEACH  01 ONE FAMILY DWELLINGS
# 3          3     BATH BEACH  01 ONE FAMILY DWELLINGS
# 4          3     BATH BEACH  01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                                1     6360     55
# 1                                1     6360    157
# 2                                1     6361     20
# 3                                1     6367     42
# 4                                1     6393     16
#
#   BUILDING CLASS AS OF FINAL ROLL 17/18             ADDRESS\n  \
# 0                                    A5    28 BAY 10TH STREET
# 1                                    A5  36 BAY 10TH   STREET
# 2                                    A5    47 BAY 10TH STREET
# 3                                    S1      1730 86TH STREET
# 4                                    A5  145 BAY 8TH   STREET
#
#   APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  \
# 0                     ...                    1                   0
# 1                     ...                    1                   0
# 2                     ...                    1                   0
# 3                     ...                    1                   1
# 4                     ...                    1                   0
#
#    TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n  \
# 0              1                1547                 1428          1930
# 1              1                1547                 1428          1930
# 2              1                1933                 1660          1930
# 3              2                1342                 1920          1926
# 4              1                1716                 1554          1920
#
#    TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n SALE PRICE\n  \
# 0                            1                                A5       725000
# 1                            1                                A5       800000
# 2                            1                                A5            0
# 3                            1                                S1      1200000
# 4                            1                                A5           10
#
#    SALE DATE\n
# 0   2017-06-27
# 1   2017-02-27
# 2   2017-03-04
# 3   2017-03-31
# 4   2017-09-15
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Ignoring headers

# %% [markdown]
# We're going to fix this by getting rid of `skiprows=` and using `header=None`. That way NONE of them will have ANY headers.
#
# Try `header=None` on one of them.
#
# (After we combine them all we'll update them with the right header rows.)

# %%
df = pd.read_excel('2017_brooklyn.xls', header=None)
df.head(5)
# Out:
#                                                   0               1   \
# 0  BROOKLYN ANNUALIZE SALE FOR 2017.  (All Sales ...             NaN
# 1  Sales File as of 4/9/2018.  Coop Sales Files a...             NaN
# 2  Neighborhood Name and Descriptive Data is as o...             NaN
# 3  Building Class Category is based on Building C...             NaN
# 4                                          BOROUGH\n  NEIGHBORHOOD\n
#
#                           2                                 3        4   \
# 0                        NaN                               NaN      NaN
# 1                        NaN                               NaN      NaN
# 2                        NaN                               NaN      NaN
# 3                        NaN                               NaN      NaN
# 4  BUILDING CLASS CATEGORY\n  TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n
#
#       5            6                                      7          8   \
# 0    NaN          NaN                                    NaN        NaN
# 1    NaN          NaN                                    NaN        NaN
# 2    NaN          NaN                                    NaN        NaN
# 3    NaN          NaN                                    NaN        NaN
# 4  LOT\n  EASE-MENT\n  BUILDING CLASS AS OF FINAL ROLL 17/18  ADDRESS\n
#
#                    9   ...                   11                  12  \
# 0                 NaN  ...                  NaN                 NaN
# 1                 NaN  ...                  NaN                 NaN
# 2                 NaN  ...                  NaN                 NaN
# 3                 NaN  ...                  NaN                 NaN
# 4  APARTMENT NUMBER\n  ...  RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n
#
#               13                  14                   15            16  \
# 0            NaN                 NaN                  NaN           NaN
# 1            NaN                 NaN                  NaN           NaN
# 2            NaN                 NaN                  NaN           NaN
# 3            NaN                 NaN                  NaN           NaN
# 4  TOTAL UNITS\n  LAND SQUARE FEET\n  GROSS SQUARE FEET\n  YEAR BUILT\n
#
#                             17                                18  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4  TAX CLASS AT TIME OF SALE\n  BUILDING CLASS AT TIME OF SALE\n
#
#              19           20
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4  SALE PRICE\n  SALE DATE\n
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Open them all at the same time!
#
# Starting from your list of filenames, use a list comprehension (similar to how we did with the Excel sheets) to create a list of dataframes.
#
# You'll probably want to cut and paste your `.read_excel` from above so that none of them come in with headers. We'll add them in later!
#
# * _**Tip:** Make sure you have 15 years of data (aka fifteen years of dataframes)_

# %%
frames = [pd.read_excel(file, header=None) for file in files]
len(frames)
# Out:
# 15

# %% [markdown]
# ## Combine them with `pd.concat`
#
# Confirm that you should have 35,8054 rows and 21 columns. If your numbers are a *little* off you probably didn't ignore headers! (In which case, go back and do that.)
#
# Your headers should just be numbers - 0, 1, 2, 3, 4.... etc.
#
# * _**Tip:** Be sure to `ignore_index=True`_

# %%
df = pd.concat(frames, ignore_index=True)

# %%
df.shape
# Out:
# (358054, 21)

# %% [markdown]
# ## Add in the headers
#
# The fourth row seems to be the headers. You can update the headers to be the info from the 4rd row.
#
# ```python
# df.columns = df.loc[3].tolist()
# ```

# %%
list = []
new_list = []

for cell in df.loc[4].tolist():
    cell.lower()
    list.append(cell)

for guy in list:
    new_list.append(guy.lower().replace(' ', '_').strip('\n'))

df.columns = new_list

# %%
df.head(2)
# Out:
#                                              borough neighborhood  \
# 0  BROOKLYN ANNUALIZE SALE FOR 2014.  (All Sales ...          NaN
# 1  Sales File as of 3/31/2015.  Coop Sales Files ...          NaN
#
#   building_class_category tax_class_at_present block  lot ease-ment  \
# 0                     NaN                  NaN   NaN  NaN       NaN
# 1                     NaN                  NaN   NaN  NaN       NaN
#
#   building_class_at_present address apartment_number  ... residential_units  \
# 0                       NaN     NaN              NaN  ...               NaN
# 1                       NaN     NaN              NaN  ...               NaN
#
#   commercial_units total_units land_square_feet gross_square_feet year_built  \
# 0              NaN         NaN              NaN               NaN        NaN
# 1              NaN         NaN              NaN               NaN        NaN
#
#   tax_class_at_time_of_sale building_class_at_time_of_sale sale_price  \
# 0                       NaN                            NaN        NaN
# 1                       NaN                            NaN        NaN
#
#   sale_date
# 0       NaN
# 1       NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Remove the notation rows from the top of the Excel sheets
#
# We used `dropna` in class on Monday to remove rows that were missing a `Treatment Date`. Let's do the same thing here to help remove some of the garbage - it seems like we can probably rely on `NEIGHBORHOOD` or `BLOCK` missing to mean that it's a garbage row.

# %%
df = df.dropna(subset=['neighborhood', 'block'])

# %%
df = df.drop(index=4)

# %%
df.head(3)
# Out:
#   borough               neighborhood  \
# 5       3  BATH BEACH
# 6       3  BATH BEACH
# 7       3  BATH BEACH
#
#                         building_class_category tax_class_at_present block  \
# 5  01  ONE FAMILY DWELLINGS                                        1  6360
# 6  01  ONE FAMILY DWELLINGS                                        1  6363
# 7  01  ONE FAMILY DWELLINGS                                        1  6363
#
#    lot ease-ment building_class_at_present  \
# 5   14                                  A5
# 6   22                                  A9
# 7  119                                  A9
#
#                                      address apartment_number  ...  \
# 5  8663 15TH   AVENUE                                          ...
# 6  8645 16TH   AVENUE                                          ...
# 7  8651 16 AVENUE                                              ...
#
#   residential_units commercial_units total_units land_square_feet  \
# 5                 1                0           1             1547
# 6                 1                0           1             2058
# 7                 1                0           1             2058
#
#   gross_square_feet year_built tax_class_at_time_of_sale  \
# 5              2224       1930                         1
# 6              1492       1930                         1
# 7              1492       1930                         1
#
#   building_class_at_time_of_sale sale_price            sale_date
# 5                             A5     450000  2014-09-08 00:00:00
# 6                             A9          0  2014-06-23 00:00:00
# 7                             A9     670000  2014-04-16 00:00:00
#
# [3 rows x 21 columns]

# %% [markdown]
# Confirm that you have **357992** rows remaining.

# %%
# Huh. Is this because I replaced the header row?

df.shape
# Out:
# (357991, 21)

# %% [markdown]
# ## Clean up the data, then remove the duplicated header rows
#
# Every Excel sheet brought in a new 'BOROUGH' and 'NEIGHBORHOOD', etc, that were supposed to be headers.
#
# Let's look at `df.BOROUGH`. Do a `value_counts()` to see whether you notice anything unexpected.

# %%
df.borough.value_counts()
# Out:
# 3            285837
# 3             72140
# BOROUGH\n         7
# BOROUGH           7
# Name: borough, dtype: int64

# %% [markdown]
# Looks like there's all sorts of spaces or newlines – instead of `3` sometimes it's `3 ` (and probably other garbage like that). In theory we could get rid of it easily using `.str.strip()`, which removes whitespace from before/after a string.
#
# ```python
# df.BOROUGH = df.BOROUGH.str.strip()
# ```
#
# The problem is this is probably a problem in *all of the columns*. [This StackOverflow answer sets you up with a pretty good option,](https://stackoverflow.com/a/45270483) but it doesn't work in some edge cases. And of course our dataset is one of them! So try this out:
#
# ```python
# df = df.apply(lambda col: col.astype(str).str.strip())
# ```
#
# `.apply` is like a for loop for pandas - this loops through every column and runs `.str.strip()` on it.

# %%
df = df.apply(lambda col: col.astype(str).str.strip())

# %% [markdown]
# Try your `value_counts()` again and let's see if it worked! It should look something like this:
#
# ```
# 3          72140
# BOROUGH       15
# Name: BOROUGH, dtype: int64
# ```

# %%
df.borough.value_counts()
# Out:
# 3          357977
# BOROUGH        14
# Name: borough, dtype: int64

# %% [markdown]
# *Now* we can finally remove all of the rows where the column `df.BOROUGH` is the string `"BOROUGH"`.

# %%
df = df[df.borough != 'BOROUGH']

# %% [markdown]
# Confirm you now have **357,977 rows**.

# %%
df.shape
# Out:
# (357977, 21)

# %% [markdown]
# ## Save the cleaned file
#
# It's good practice to save your cleaned data before you start your analysis. Use `.to_csv` to save the cleaned data, passing `index=False` so it doesn't save the index.

# %%
df.to_csv('brooklyn.csv',index=False)

# %%
# !ls
# Out:
# 7316.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 01 - Data Acquisition.ipynb 2016_brooklyn.xls
# 02 - Data Compilation.ipynb 2016_brooklyn.xls.1
# 03 - Data Analysis.ipynb    2017_brooklyn.xls
# 04 - Data Exploration.ipynb 2017_brooklyn.xls.1
# 2009_brooklyn.xls           2018_brooklyn.xlsx
# 2009_brooklyn.xls.1         2018_brooklyn.xlsx.1
# 2010_brooklyn.xls           2019_brooklyn.xlsx
# 2010_brooklyn.xls.1         2019_brooklyn.xlsx.1
# 2011_brooklyn.xls           2020_brooklyn.xlsx
# 2011_brooklyn.xls.1         2020_brooklyn.xlsx.1
# 2012_brooklyn.xls           2021_brooklyn.xlsx
# 2012_brooklyn.xls.1         2021_brooklyn.xlsx.1
# 2013_brooklyn.xls           brooklyn.csv
# 2013_brooklyn.xls.1         cleaned.csv
# 2014_brooklyn.xls           merged.csv
# 2014_brooklyn.xls.1         sales_2007_brooklyn.xls
# 2015_brooklyn.xls           sales_2008_brooklyn.xls
# 2015_brooklyn.xls.1         urls.txt
