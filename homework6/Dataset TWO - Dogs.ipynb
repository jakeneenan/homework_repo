# %% [markdown]
# # Homework 6, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel('NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx', nrows=30000)

df.head(5)
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M               Unknown
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M               Unknown
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# 1                NaN   2013-04-01             No               No        Yes
# 2                NaN   2014-09-01            Yes              NaN         No
# 3                NaN   2008-04-01            Yes               No        Yes
# 4                NaN   2014-01-01             No              NaN         No
#
#          Application Date License Issued Date License Expired Date
# 0 2012-09-19 16:01:19.647          2015-09-19           2016-09-19
# 1 2013-09-20 11:41:36.647          2014-09-20           2018-09-20
# 2 2014-09-12 13:13:36.713          2014-09-12           2019-09-12
# 3 2014-09-12 15:26:51.417          2014-09-12           2017-10-20
# 4 2014-09-12 15:43:17.707          2014-09-12           2019-09-12

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %%
df.shape
# Out:
# (30000, 15)

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %% [markdown]
# Each row is a dog registered in NYC (as of 2016). Animal Birth is the animal's birthday, and Animal Gender is the dog's sex.

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [markdown]
# These all have the caveat of applying only to dogs registered in NYC as of April 2016.
#
# 1. How many unvaccinated dogs are registered?
# 2. What is the most common dog name?
# 3. What is the average turn around time for license issuing?
# 4. WHat percentage of dogs are spayed/neutered?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df['Primary Breed'].value_counts().head(10)
# Out:
# Unknown                                 4777
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %%
df[(df['Primary Breed'] != 'Unknown')]['Primary Breed'].value_counts().head(10)
# Out:
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Beagle                                   546
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## What are the most popular dog names?

# %%
df[(df['Animal Name'] != 'Unknown') & (df['Animal Name'] != 'UNKNOWN')]['Animal Name'].value_counts()
# Out:
# Max              202
# Bella            193
# Charlie          172
# Lola             146
# Rocky            140
#                 ...
# Bluno              1
# DARBY              1
# CHARLEY VIVAR      1
# TINY               1
# Squeeze            1
# Name: Animal Name, Length: 13719, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'] == 'Jake']['Animal Name'].value_counts()
# Out:
# Jake    34
# Name: Animal Name, dtype: int64

# %%
df[df['Animal Name'] == 'Max']['Animal Name'].value_counts()
# Out:
# Max    202
# Name: Animal Name, dtype: int64

# %%
df[df['Animal Name'] == 'Maxwell']['Animal Name'].value_counts()
# Out:
# Maxwell    11
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
df['Guard or Trained'].value_counts(normalize=True)
# Out:
# No     0.999143
# Yes    0.000857
# Name: Guard or Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df['Guard or Trained'].value_counts()
# Out:
# No     19809
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %%
# It is not! You need to tell .value_counts to keep those na values

df['Guard or Trained'].value_counts(dropna=False)
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# Then check your result with another `.value_counts()`

# %%
df['Guard or Trained'] = df["Guard or Trained"].replace({
    None: 'No'
})

df['Guard or Trained'].value_counts(dropna=False)
# Out:
# No     29983
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
df[df['Guard or Trained'] == 'Yes']['Primary Breed'].value_counts()
# Out:
# Unknown                       5
# German Shepherd Dog           3
# Poodle, Standard              1
# German Shepherd Crossbreed    1
# Labrador Retriever            1
# Doberman Pinscher             1
# Shih Tzu                      1
# Rottweiler                    1
# Golden Retriever              1
# Schnauzer, Miniature          1
# Yorkshire Terrier             1
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
years = []

years = df['Animal Birth'].apply(lambda birth: birth.year)

df['Year'] = years

df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M               Unknown
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M               Unknown
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# 1                NaN   2013-04-01             No               No        Yes
# 2                NaN   2014-09-01            Yes               No         No
# 3                NaN   2008-04-01            Yes               No        Yes
# 4                NaN   2014-01-01             No               No         No
#
#          Application Date License Issued Date License Expired Date  Year
# 0 2012-09-19 16:01:19.647          2015-09-19           2016-09-19  2007
# 1 2013-09-20 11:41:36.647          2014-09-20           2018-09-20  2013
# 2 2014-09-12 13:13:36.713          2014-09-12           2019-09-12  2014
# 3 2014-09-12 15:26:51.417          2014-09-12           2017-10-20  2008
# 4 2014-09-12 15:43:17.707          2014-09-12           2019-09-12  2014

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
age = []

age = 2022 - df['Year']

df['Age'] = age

df['Age'].median()
# Out:
# 12.0

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
df2 = pd.read_csv('zipcodes-neighborhoods.csv')

df = df.join(df2.set_index('zip'),on='Owner Zip Code')
df.head(20)
# Out:
#     Owner Zip Code            Animal Name Animal Gender  \
# 0            10024              BLUE MACK             M
# 1            10461           Indie Zephir             M
# 2            10013                  Bilal             M
# 3            10025                  Buddy             M
# 4            10013                    Ali             M
# 5            10013                  Queen             F
# 6            10035       Paige Sable Orta             F
# 7            10465                   Yogi             M
# 8            10013              Chewbacca             F
# 9            10013             IAN                    M
# 10           10028                   Lola             F
# 11           11232                 muneca             F
# 12           10022              Elizabeth             F
# 13           11209                 Benson             M
# 14           10025                 Dottie             F
# 15           11215          Lucy Moo Jung             F
# 16           10025  Apple Wazowski Panwar             M
# 17           10312                  Buddy             M
# 18           11220                  Ricky             M
# 19           10002                  Avery             F
#
#                            Primary Breed  Secondary Breed  \
# 0                                Unknown    AIREDALE TERR
# 1                             Rottweiler              NaN
# 2                   Australian Cattledog              NaN
# 3                                Unknown         Cockapoo
# 4                                Basenji              NaN
# 5                       Akita Crossbreed              NaN
# 6   American Pit Bull Mix / Pit Bull Mix              NaN
# 7                                  Boxer              NaN
# 8          Labrador Retriever Crossbreed              NaN
# 9                                Unknown  GREYHOUND TER X
# 10                               Maltese              NaN
# 11                                Beagle              NaN
# 12         Cavalier King Charles Spaniel              NaN
# 13                                 Boxer              NaN
# 14                      Poodle, Standard              NaN
# 15       Dachshund Smooth Coat Miniature              NaN
# 16                              Havanese              NaN
# 17                          Bull Terrier              NaN
# 18                   German Shepherd Dog              NaN
# 19    American Pit Bull Terrier/Pit Bull              NaN
#
#    Animal Dominant Color Animal Secondary Color Animal Third Color  \
# 0                  BROWN                  BLACK                NaN
# 1                  BLACK                    TAN                NaN
# 2                   Rust                    NaN                NaN
# 3                  BLOND                  WHITE                NaN
# 4                  Black                    NaN                NaN
# 5               Charcoal                    Red                NaN
# 6                  White                   Gray                NaN
# 7                    TAN                  BLACK                NaN
# 8                    RED                    NaN                NaN
# 9                  WHITE                  BLACK                NaN
# 10               Apricot                  White                NaN
# 11                 White                  Black              Brown
# 12                 Brown                  White                NaN
# 13               BRINDLE                    NaN                NaN
# 14                 Cream                    NaN                NaN
# 15                 White                  Black                NaN
# 16                 WHITE                  BLACK                NaN
# 17                 BLACK                  WHITE                NaN
# 18                 Black                    Tan                NaN
# 19                  Gray                    NaN                NaN
#
#    Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0    2007-11-01            Yes               No        Yes
# 1    2013-04-01             No               No        Yes
# 2    2014-09-01            Yes               No         No
# 3    2008-04-01            Yes               No        Yes
# 4    2014-01-01             No               No         No
# 5    2013-04-01             No               No        Yes
# 6    2014-07-01             No               No         No
# 7    2010-09-01            Yes               No        Yes
# 8    2012-06-01            Yes               No        Yes
# 9    2006-01-01            Yes               No        Yes
# 10   2009-06-01            Yes               No        Yes
# 11   2013-05-01            Yes               No        Yes
# 12   2013-03-01            Yes               No        Yes
# 13   2010-07-01            Yes               No        Yes
# 14   2013-04-01            Yes               No        Yes
# 15   2014-03-01            Yes               No        Yes
# 16   2013-07-01            Yes               No         No
# 17   2012-10-01            Yes               No        Yes
# 18   2014-07-01             No               No         No
# 19   2014-06-01             No               No         No
#
#           Application Date License Issued Date License Expired Date  Year  \
# 0  2012-09-19 16:01:19.647          2015-09-19           2016-09-19  2007
# 1  2013-09-20 11:41:36.647          2014-09-20           2018-09-20  2013
# 2  2014-09-12 13:13:36.713          2014-09-12           2019-09-12  2014
# 3  2014-09-12 15:26:51.417          2014-09-12           2017-10-20  2008
# 4  2014-09-12 15:43:17.707          2014-09-12           2019-09-12  2014
# 5  2014-09-12 16:14:48.487          2014-09-12           2017-09-12  2013
# 6  2014-09-12 16:22:54.113          2014-09-12           2017-09-12  2014
# 7  2014-09-12 16:47:35.317          2014-09-12           2017-10-02  2010
# 8  2014-09-12 17:42:56.647          2014-09-12           2019-10-01  2012
# 9  2014-09-12 19:09:19.020          2014-09-12           2019-10-30  2006
# 10 2014-09-12 22:07:33.697          2014-09-12           2017-10-09  2009
# 11 2014-09-13 00:58:36.603          2014-09-13           2019-09-13  2013
# 12 2014-09-13 07:07:54.303          2014-09-13           2019-09-13  2013
# 13 2014-09-13 11:14:34.093          2014-09-13           2019-10-29  2010
# 14 2014-09-13 11:28:32.237          2014-09-13           2017-09-13  2013
# 15 2014-09-13 13:40:23.943          2014-09-13           2019-09-13  2014
# 16 2014-09-13 14:13:16.553          2014-09-13           2019-10-16  2013
# 17 2014-09-13 14:23:18.100          2014-09-13           2019-10-05  2012
# 18 2014-09-13 15:40:08.160          2014-09-13           2017-09-13  2014
# 19 2014-09-13 15:55:11.457          2014-09-13           2019-09-13  2014
#
#     Age                   neighborhood        borough
# 0    15                Upper West Side      Manhattan
# 1     9                Southeast Bronx          Bronx
# 2     8     Greenwich Village and Soho      Manhattan
# 3    14                Upper West Side      Manhattan
# 4     8     Greenwich Village and Soho      Manhattan
# 5     9     Greenwich Village and Soho      Manhattan
# 6     8                    East Harlem      Manhattan
# 7    12                Southeast Bronx          Bronx
# 8    10     Greenwich Village and Soho      Manhattan
# 9    16     Greenwich Village and Soho      Manhattan
# 10   13                Upper East Side      Manhattan
# 11    9                    Sunset Park       Brooklyn
# 12    9  Gramercy Park and Murray Hill      Manhattan
# 13   12             Southwest Brooklyn       Brooklyn
# 14    9                Upper West Side      Manhattan
# 15    8             Northwest Brooklyn       Brooklyn
# 16    9                Upper West Side      Manhattan
# 17   10                    South Shore  Staten Island
# 18    8                    Sunset Park       Brooklyn
# 19    8                Lower East Side      Manhattan

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
df[df.borough == 'Bronx']['Animal Name'].value_counts()
# Out:
# Bella                   22
# Max                     21
# Rocky                   20
# Unknown                 16
# Lucky                   15
#                         ..
# General                  1
# BAILEY                   1
# Spice Shiloh Carwell     1
# Jackie E.                1
# toby                     1
# Name: Animal Name, Length: 2032, dtype: int64

# %%
df[df.neighborhood == 'Upper East Side']['Animal Name'].value_counts()
# Out:
# Charlie    19
# Bella      12
# NO NAME    11
# Lucy       10
# Lola       10
#            ..
# Jogi        1
# Peeby       1
# Carly       1
# Caddock     1
# KILO        1
# Name: Animal Name, Length: 1383, dtype: int64

# %%
df[df.borough == 'Brooklyn']['Animal Name'].value_counts()
# Out:
# Unknown      97
# Max          46
# UNKNOWN      45
# Bella        45
# unknown      45
#              ..
# EMMIE         1
# Jimmi         1
# Clifford      1
# Amanda        1
# Beckett       1
# Name: Animal Name, Length: 4539, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
df[df['Primary Breed'] != 'Unknown'].groupby('neighborhood')['Primary Breed'].describe()
# Out:
#                               count unique  \
# neighborhood
# Borough Park                    531     99
# Bronx Park and Fordham          305     61
# Bushwick and Williamsburg       525    101
# Canarsie and Flatlands          456     92
# Central Bronx                   231     52
# Central Brooklyn                621    119
# Central Harlem                  453     92
# Central Queens                  259     61
# Chelsea and Clinton            1302    132
# East Harlem                     432     90
# East New York and New Lots      265     70
# Flatbush                        383     87
# Gramercy Park and Murray Hill   868    119
# Greenpoint                      453     95
# Greenwich Village and Soho      630    123
# High Bridge and Morrisania      243     56
# Hunts Point and Mott Haven      224     55
# Inwood and Washington Heights   646    117
# Jamaica                         330     76
# Kingsbridge and Riverdale       318     90
# Lower East Side                 964    123
# Lower Manhattan                 378     90
# Mid-Island                      402     78
# North Queens                    653    103
# Northeast Bronx                 234     58
# Northeast Queens                289     66
# Northwest Brooklyn             1431    153
# Northwest Queens                700    117
# Port Richmond                   261     69
# Rockaways                       242     61
# South Shore                    1108    116
# Southeast Bronx                 789    102
# Southeast Queens                303     70
# Southern Brooklyn               701    101
# Southwest Brooklyn              682    102
# Southwest Queens                579     94
# Stapleton and St. George        455     98
# Sunset Park                     268     74
# Upper East Side                1544    148
# Upper West Side                1642    157
# West Central Queens             809    112
# West Queens                     950    108
#
#                                                                 top freq
# neighborhood
# Borough Park                                      Yorkshire Terrier   49
# Bronx Park and Fordham                            Yorkshire Terrier   39
# Bushwick and Williamsburg                         Yorkshire Terrier   47
# Canarsie and Flatlands                                     Shih Tzu   56
# Central Bronx                                     Yorkshire Terrier   29
# Central Brooklyn                                           Shih Tzu   52
# Central Harlem                                            Chihuahua   48
# Central Queens                                    Yorkshire Terrier   34
# Chelsea and Clinton                                       Chihuahua   80
# East Harlem                                       Yorkshire Terrier   44
# East New York and New Lots                        Yorkshire Terrier   25
# Flatbush                                                   Shih Tzu   38
# Gramercy Park and Murray Hill                     Yorkshire Terrier   52
# Greenpoint                                                Chihuahua   40
# Greenwich Village and Soho                       Labrador Retriever   35
# High Bridge and Morrisania                                 Shih Tzu   33
# Hunts Point and Mott Haven                                Chihuahua   37
# Inwood and Washington Heights                             Chihuahua   48
# Jamaica                                           Yorkshire Terrier   41
# Kingsbridge and Riverdale                                  Shih Tzu   26
# Lower East Side                                           Chihuahua   77
# Lower Manhattan                                            Shih Tzu   24
# Mid-Island                                        Yorkshire Terrier   36
# North Queens                                                Maltese   54
# Northeast Bronx                                   Yorkshire Terrier   35
# Northeast Queens                                            Maltese   29
# Northwest Brooklyn                               Labrador Retriever   72
# Northwest Queens                                          Chihuahua   62
# Port Richmond                  American Pit Bull Mix / Pit Bull Mix   22
# Rockaways                                                  Shih Tzu   24
# South Shore                                                Shih Tzu   90
# Southeast Bronx                                            Shih Tzu   83
# Southeast Queens                                  Yorkshire Terrier   35
# Southern Brooklyn                                 Yorkshire Terrier   85
# Southwest Brooklyn                                         Shih Tzu   69
# Southwest Queens                                  Yorkshire Terrier   53
# Stapleton and St. George                                   Shih Tzu   33
# Sunset Park                                       Yorkshire Terrier   32
# Upper East Side                                            Havanese   94
# Upper West Side                                  Labrador Retriever  121
# West Central Queens                               Yorkshire Terrier   72
# West Queens                                                Shih Tzu   95

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?

# %%
# Found rank in the documentation for dataframes. Not sure if that's the best way to go about it

df[(df['Primary Breed'] != 'Unknown')].groupby('Primary Breed')['Spayed or Neut'].value_counts(normalize=True).rank().sort_values()
# Out:
# Primary Breed                  Spayed or Neut
# Bassett Hound                  No                  1.0
# Greyhound                      No                  2.0
# German Shepherd Crossbreed     No                  3.0
# Welsh Corgi, Cardigan          No                  4.0
# Labrador Retriever Crossbreed  No                  5.0
#                                                  ...
# Petit Basset Griffon Vendeen   Yes               392.5
# Peruvian Inca Orchid           Yes               392.5
# Parson Russell Terrier         Yes               392.5
# Black and Tan Coonhound        Yes               392.5
# Dandie Dinmont Terrier         Yes               392.5
# Name: Spayed or Neut, Length: 428, dtype: float64

# %%
# There are only three non-recorded genders, I just tossed them

df[df['Animal Gender'] != ' '].groupby('Animal Gender')['Spayed or Neut'].value_counts(normalize=True)
# Out:
# Animal Gender  Spayed or Neut
# F              Yes               0.857850
#                No                0.142150
# M              Yes               0.791856
#                No                0.208144
# Name: Spayed or Neut, dtype: float64

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
monochrome = 'No'

df['Monochrome'] = monochrome

# %%
df.loc[((df['Animal Dominant Color'] == 'Black') | (df['Animal Dominant Color'] == 'White') | (df['Animal Dominant Color'] == 'Grey')) & ((df['Animal Secondary Color'].isna()) & (df['Animal Third Color'].isna())), 'Monochrome'] = 'Yes'

df.Monochrome.value_counts()
# Out:
# No     28609
# Yes     1391
# Name: Monochrome, dtype: int64

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
df.borough.value_counts(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
df3 = pd.read_csv('boro_population.csv')

df = df.join(df3.set_index('borough'),on='borough')

# %%
df3.head()
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
# This one is really getting me.

df.loc[:, ['borough', 'Animal Name', 'population']].groupby('borough').describe()
# Out:
#               population                                                   \
#                    count       mean  std        min        25%        50%
# borough
# Bronx             2748.0  1455444.0  0.0  1455444.0  1455444.0  1455444.0
# Brooklyn          7466.0  2636735.0  0.0  2636735.0  2636735.0  2636735.0
# Manhattan        10478.0  1644518.0  0.0  1644518.0  1644518.0  1644518.0
# Queens            6154.0  2339150.0  0.0  2339150.0  2339150.0  2339150.0
# Staten Island     2727.0   474558.0  0.0   474558.0   474558.0   474558.0
#
#
#                      75%        max
# borough
# Bronx          1455444.0  1455444.0
# Brooklyn       2636735.0  2636735.0
# Manhattan      1644518.0  1644518.0
# Queens         2339150.0  2339150.0
# Staten Island   474558.0   474558.0

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %%
# Stack Overflow original here, have never encountered the level parameter

df[df['Primary Breed'] != 'Unknown'].groupby('borough')['Primary Breed'].value_counts().groupby(level=0).head().plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='borough,Primary Breed'>

# %% [markdown]
# ## What percentage of dogs are not guard dogs?

# %%
df['Guard or Trained'].value_counts(normalize=True) *100
# Out:
# No     99.943333
# Yes     0.056667
# Name: Guard or Trained, dtype: float64
